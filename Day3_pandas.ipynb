# %%
import pandas as pd

# %%
#Series
A=["ANIMAL","tiger",'lion','giraffy']
R=pd.Series(A,index=["SI.NO",1,2,3]) #pd.Series(col,index)
print(R)
# Out:
# SI.NO     ANIMAL
# 1          tiger
# 2           lion
# 3        giraffy
# dtype: object

# %%
col=["Joe","John"]
index=[1,2]
r=pd.Series(col,index)
print(r)
# Out:
# 1     Joe
# 2    John
# dtype: object

# %%
dia=pd.read_csv("/content/diabetcsv.csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grad=pd.read_csv("/content/grades.txt")
grad
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade
# 0                  Joe K 9.8 10 9.9 A+
# 1               Rajesh M 8.9 9.1 9.3 A
# 2               Kissan V 9.9 9.3 9.2 A
# 3                   Mary N 7.7 8 7.1 B
# 4                Jeen K 9.8 9.1 9.9 A+
# 5                  Raj M 8.9 9.1 9.3 A
# 6                 Hassan V 9.9 9 9.2 A
# 7                   Mari N 7.7 8 7.1 B
# 8                Jess K 9.8 9.1 9.9 A+
# 9                 Rajini M 7 9.1 9.3 A
# 10               Kiran V 9.9 9.3 9.2 A
# 11                  Maya N 7.7 8 7.1 B
# 12              Jolin K 9.8 9.1 9.9 A+
# 13                  Riya M 8 9.1 9.3 A
# 14                Sana V 9.9 9.3 9.2 A
# 15                    Mark N 7.7 8 7 B

# %%
grad1=pd.read_csv("/content/grades_withnulls.csv")
grad1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
grad2=pd.read_csv("/content/grades_withnulls.txt")
grad2
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
dia1=pd.read_excel("/content/diabetes.xlsx")
dia1
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
demo=pd.read_csv("/content/demodt.txt")
demo
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
dia1.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
#shape
dia=pd.read_csv("/content/diabetcsv.csv")
dia
print(dia.shape)
print(dia.shape[0])
print(dia.shape[1])
# Out:
# (768, 9)
# 768
# 9

# %%
grad1=pd.read_csv("/content/grades_withnulls.csv")
grad1
print(grad1.isnull()) #checking null in file
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
print(grad1.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
grad1.dropna() #it drops null values
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
grad1.dropna(inplace=True)
print(grad1)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
grad1=pd.read_csv("/content/grades_withnulls.csv")
grad1.fillna(0) #replace nan values into given value
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   0.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   0.0   9.1   9.9    A+       1
# 9   Rajini        M   0.0   9.1   9.3     A       0
# 10   Kiran        V   0.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
mv=grad1['SEM1'].mean()
print(mv)
grad1.fillna(mv,inplace=True)
grad1
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#iloc=integer location,index
#loc=field names,index
#dfname.loc[0] first record
print("first record:")
print(grad2.loc[0])

#dfname.loc[St:stop]
print("\n\n0 to 5 records:")
print(grad2.loc[0:5])

#dfname.iloc[r_ind:col_ind]
print("\n\n10 to 12 records:")
grad2.iloc[10:13]
# Out:
# first record:
# Names Initials SEM1 SEM2 SEM3 Grade Placed    Joe K 9.8 10 9.9 A+ 1
# Name: 0, dtype: object
#
#
# 0 to 5 records:
#   Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                      Joe K 9.8 10 9.9 A+ 1
# 1                  Rajesh M 8.9 9.1 9.3 A 1
# 2                    Kissan V 9.9 9.8 10 A 0
# 3                       Mary N 7.7 8 NaN B 0
# 4                    Jeen K 9.8 9.1 9.9 A+ 1
# 5                      Raj M 8.9 9.1 9.3 A 1
#
#
# 10 to 12 records:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1

# %%
#To print records who score 9.3 in sem 3
grad1.loc[grad1.SEM1>9.8,"Names"]
# Out:
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
#print the grades of students who scored more than 9.8 in sem1
grad1.loc[grad1.SEM1>9,"Grade"]
# Out:
# 0     A+
# 2      A
# 4     A+
# 6      A
# 12    A+
# 14     A
# 15     A
# Name: Grade, dtype: object

# %%
#accessing the records with sem3>9.7 but printing only grade column
grad1.loc[grad1.SEM3>9.7,"Grade"]
# Out:
# 0     A+
# 2      A
# 4     A+
# 8     A+
# 12    A+
# 14     A
# Name: Grade, dtype: object

# %%
grad1.drop_duplicates(inplace=True)
grad1
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
grad1.head(7)
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1
# 6  Hassan        V   9.9   9.0   9.200000     A       1

# %%
grad1.tail(7)
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 11    Maya        N  7.700000   8.0   7.1     B       0
# 12   Jolin        K  9.800000   9.1   9.9    A+       1
# 14    Riya        M  9.300000   9.9  10.0     A       1
# 15    Sana        V  9.900000   9.3   9.2     A       0
# 16    Mark        N  7.700000   8.0   7.0     B       0

# %%
#accessing index functions
print(grad1.loc[grad1.index==7])
print("grade:")
print(grad1.loc[grad1.index==7,"Grade"])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
# grade:
# 7    B
# Name: Grade, dtype: object

# %%
#print all columns names
grad1=pd.read_csv("/content/grades_withnulls.csv")
grad1
col=grad1.columns
print(col)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#columns list
col_list=list(grad1.columns)
print(col_list)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#add new column
grad1["conduct"]="Good"
grad1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good
# 3     Mary        N   7.7   8.0   NaN     B       0    Good
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good
# 5      Raj        M   8.9   9.1   9.3     A       1    Good
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good
# 7     Mari        N   7.7   8.0   7.1     B       1    Good
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good
# 11    Maya        N   7.7   8.0   7.1     B       0    Good
# 12   Jolin        K   9.8   9.1   9.9    A+       1    Good
# 13  Rajesh        M   8.9   9.1   9.3     A       1    Good
# 14    Riya        M   9.3   9.9  10.0     A       1    Good
# ...

# %%
#create new col averagevfor sem1,2,3
grad1["Average"]=(grad1["SEM1"]+grad1["SEM2"]+grad1["SEM3"])/3
grad1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed conduct   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1    Good  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1    Good  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0    Good  9.900000
# 3     Mary        N   7.7   8.0   NaN     B       0    Good       NaN
# 4     Jeen        K   9.8   9.1   9.9    A+       1    Good  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1    Good  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1    Good  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1    Good  7.600000
# 8     Jess        K   NaN   9.1   9.9    A+       1    Good       NaN
# 9   Rajini        M   NaN   9.1   9.3     A       0    Good       NaN
# 10   Kiran        V   NaN   9.3   9.2     A       0    Good       NaN
# 11    Maya        N   7.7   8.0   7.1     B       0    Good  7.600000
# ...
